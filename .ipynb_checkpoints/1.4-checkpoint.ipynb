# %%
from keras.models import Sequential, Model, load_model
from keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.preprocessing.image import load_img
# from keras.preprocessing.image import ImageDataGenerator, load_ig, img_to_array
from keras.layers import *
from keras.optimizers import *
from keras.callbacks import Callback, EarlyStopping
from keras.utils import to_categorical
from sklearn.metrics import confusion_matrix
import tensorflow as tf
import matplotlib.pyplot as plt
import os
import glob
import cv2
import numpy as np
import pandas as pd
from PIL import Image
from pathlib import Path
import tensorflow as tf
import matplotlib.pyplot as plt
from random import shuffle
from tqdm import tqdm
# %matplotlib inline

# %%
data_dir = Path("Dataset/Curve_NoCurve_Dataset/Curve_NoCurve_Dataset/")

train_data_curve = data_dir/"train/curve"
train_data_nocurve = data_dir/"train/no_curve"

test_data_curve = data_dir/"test/curve"
test_data_nocurve = data_dir/"test/no_curve"

# %%
def train_data_with_label(pathh):
    train_images = []
    
    for i in tqdm(os.listdir(pathh)):
        path = os.path.join(pathh, i)
        img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
#         img = cv2.resize(img, 256, 256)
        train_images.append([np.array(img)])
        
    shuffle(train_images)
    return train_images

# %%
def test_data_with_label(pathh):
    test_images = []
    
    for i in tqdm(os.listdir(pathh)):
        path = os.path.join(pathh, i)
        img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
#         img = cv2.resize(img, 256, 256)
        test_images.append([np.array(img)])

    return test_images

# %%
## Training Images
train_images1 = train_data_with_label(train_data_curve)
train_images2 = train_data_with_label(train_data_nocurve)
train_image = np.append(train_images1, train_images2)
train_image = train_image.reshape(-1,256, 256, 1)

## Training Labels
label1 = np.ones(len(train_images1),dtype=np.int8) 
label2 = np.zeros(len(train_images2), dtype=np.int8)
train_label = np.append(label1, label2)

## Shuffling Dataset
c = list(zip(train_image, train_label))
shuffle(c)
train_image , train_label = zip(*c)
train_image = np.asarray(train_image)
train_label = np.asarray(train_label)

## Testing Images
test_images1 = test_data_with_label(test_data_curve)
test_images2 = test_data_with_label(test_data_nocurve)
test_image = np.append(test_images1, test_images2)
test_image = test_image.reshape(-1, 256, 256, 1)

## Testing Labels
label1 = np.ones(len(test_images1),dtype=np.int8) 
label2 = np.zeros(len(test_images2), dtype=np.int8)
test_label = np.append(label1, label2)

## Shuffling Dataset
d = list(zip(test_image, test_label))
shuffle(d)
test_image, test_label = zip(*d)
test_image = np.asarray(test_image)
test_label = np.asarray(test_label)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 450/450 [00:00<00:00, 1674.76it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 450/450 [00:00<00:00, 1582.12it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 1186.01it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 50/50 [00:00<00:00, 1562.30it/s]

# %%
print("Train Image : ", train_image.shape)
print("Train Labels: ", train_label.shape)
print("Test Image  : ", test_image.shape)
print("Test Labels: ", test_label.shape)
# Out:
# Train Image :  (900, 256, 256, 1)
# Train Labels:  (900,)
# Test Image  :  (100, 256, 256, 1)
# Test Labels:  (100,)

# %%
model = Sequential()

model.add( InputLayer( input_shape=[256, 256, 1]))
model.add(Conv2D(filters=32, kernel_size=5, strides=1, padding='same',activation='relu'))
model.add(MaxPool2D(pool_size=5,padding='same'))

model.add(Conv2D(filters=50, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPool2D(pool_size=5, padding='same'))

model.add(Conv2D(filters=80, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPool2D(pool_size=5, padding='same'))

model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(rate=0.5))
model.add(Dense(1, activation='softmax')) # i changed this Dense 2 -> 1, and its not giving error of Dimensions not matching (900,1) with (900,2)

optimizer = Adam(lr=1e-3)

model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=["accuracy"])
model.fit(x=train_image, y=train_label, epochs=2, batch_size=50)
# Out:
# Epoch 1/2
# 18/18 [==============================] - 15s 795ms/step - loss: 0.0000e+00 - accuracy: 0.5000
# Epoch 2/2
# 18/18 [==============================] - 14s 799ms/step - loss: 0.0000e+00 - accuracy: 0.5000

# %%
fig = plt.figure(figsize=(14, 14))

for i in range(len(test_image)):
    data = test_image[i]
    data = data.reshape(1,256,256,1)
    cnt  = test_label[i]
    y = fig.add_subplot(6,6,1)
    model_out = model.predict([data])
    print("Actual : ", cnt)
    print("Predicted : ", model_out)
    if np.argmax(model_out) == 1:
        str_label = "Curve"
    else:
        str_label = "No_Curve"
    
    y.imshow(img, cmap='gray')
    plt.title(str_label)
    y.axes.get_xaxis().set_visible(False)
    y.axes.get_yaxis().set_visible(False)
# Out:
# 1/1 [==============================] - 0s 23ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 21ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 21ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 21ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 20ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 20ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 23ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 23ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 22ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 22ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 21ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 20ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 23ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 21ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 33ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 33ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 23ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 21ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 27ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 21ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 22ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 25ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 21ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 22ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 22ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 22ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 22ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 23ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 23ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 22ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 22ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 21ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 21ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 21ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 21ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 21ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 20ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 21ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 21ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 21ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 21ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 22ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 21ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 23ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 30ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 30ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 22ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 23ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 23ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 21ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 23ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 22ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 22ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 21ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 21ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 25ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 28ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 24ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 23ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 23ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 23ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 23ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 22ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 23ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 22ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 21ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 25ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 26ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 29ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 24ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 26ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 23ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 21ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 23ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 22ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 23ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 21ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 21ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 21ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 22ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 21ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 21ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 21ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 20ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 21ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 21ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 21ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 23ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 22ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 21ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 20ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 21ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 28ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 25ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 22ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 22ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 22ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 20ms/step
# Actual :  0
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 20ms/step
# Actual :  1
# Predicted :  [[1.]]
# 1/1 [==============================] - 0s 22ms/step
# Actual :  0
# Predicted :  [[1.]]
